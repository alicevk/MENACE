# %% [markdown]
# # Plotando as etatísticas dos jogos

# %%
# -------------------------------- Importações ------------------------------- #
from api import plot
import pickle

# %%
# ------------------------- Para plotar um histórico ------------------------- #
path = './assets/dados/history_IPA_A.pickle'

with open(path, 'rb') as file:
    data = pickle.load(file)
    plot(data[0],data[1],data[2],show=True,label1='Vitórias do jogador',label2='Vitórias do MENACE')

# %%
# # ----------------- Para plotar todos os históricos na pasta ----------------- #
# import glob
# stat_pattern = './assets/dados/history_*.pickle'

# file_paths = glob.glob(stat_pattern)

# for path in file_paths:
#     with open(path, 'rb') as file:
#         data = pickle.load(file)
#         plot(data[0],data[1],data[2],show=True,label1='Vitórias do jogador',label2='Vitórias do MENACE')
